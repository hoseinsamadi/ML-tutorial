# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('..\DataSet\Data Regression\Data_Product.csv')

print(df.to_string())
# Out:
#        fl_PullLine2  fl_DrainLine2  fl_SumDrains  fl_Total fl_Time  fl_PullLine1  fl_DrainLine1
# 0              8820            532          1252     18512     NaN          8440            720
# 1              8220            576          1368     18698    8:00          9110            792
# 2               545             54           599      1156    8:00            12            545
# 3                54             54            99       174    8:00            21             45
# 4              8260            547             0         0    8:00          9200            777
# 5              8150            561             0         0     NaN          9100            777
# 6              8280            547             0         0     NaN          8810            763
# 7              8260            532             0         0   11:00          9000            748
# 8              8150            547             0         0   12:00          8970            777
# ...
